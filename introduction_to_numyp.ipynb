# %% [markdown]
# <a href="https://colab.research.google.com/github/adityasonawale1212/Practice-_problems/blob/main/introduction_to_numyp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Create a 1D array
arr = np.array([1, 2, 3, 4])

# Math operation applied to every element instantly (Vectorization)
print(arr * 2)
# Output: [2, 4, 6, 8]
# Out:
# [2 4 6 8]

# %%
import pandas as pd

# Create a DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Salary': [50000, 60000, np.nan] # Integrated with NumPy for missing values
}
df = pd.DataFrame(data)

# Filter rows where Age is greater than 28
filtered_df = df[df['Age'] > 28]
print(filtered_df)
# Out:
#       Name  Age   Salary
# 1      Bob   30  60000.0
# 2  Charlie   35      NaN
